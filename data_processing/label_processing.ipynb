# %%
import os
import json

# %%
# Example style mappings based on the categories in your image
style_mapping = {
    "트래디셔널": {"클래식": 1, "프레피": 2},
    "매니시": {"매니시": 3, "톰보이": 4},
    "페미닌": {"페미닌": 5, "로맨틱": 6, "섹시": 7},
    "에스닉": {"히피": 8, "웨스턴": 9, "오리엔탈": 10},
    "컨템포러리": {"모던": 11, "소피스트케이티드": 12, "아방가르드": 13},
    "내추럴": {"컨트리": 14, "리조트": 15},
    "젠더플루이드": {"젠더리스": 16},
    "스포티": {"스포티": 17},
    "서브컬처": {"레트로": 18, "키치/키덜트": 19, "힙합": 20, "핑크": 21},
    "캐주얼": {"밀리터리": 22, "스트리트": 23}
}

# %%
def encode_style(style_category, style_name):
    if style_category in style_mapping and style_name in style_mapping[style_category]:
        return style_mapping[style_category][style_name]
    return 0  # Default value for unknown style

# %%
top_category_mapping = {
    "탑": 1, "블라우스": 2, "티셔츠": 3, "니트웨어": 4, "셔츠": 5, "브라탑": 6, "후드티": 7
}
bottom_category_mapping = {
    "청바지": 1, "팬츠": 2, "스커트": 3, "레깅스": 4, "조거팬츠": 5
}
outer_category_mapping = {
    "코트": 1, "재킷": 2, "점퍼": 3, "패딩": 4, "베스트": 5, "가디건": 6, "집업": 7
}
dress_category_mapping = {
    "드레스": 1, "점프수트": 2
}
color_mapping = {
    "블랙": 1, "화이트": 2, "그레이": 3, "레드": 4, "핑크": 5, "오렌지": 6, "베이지": 7,
    "브라운": 8, "옐로우": 9, "그린": 10, "카키": 11, "실버": 12
}
material_mapping = {
    "우븐": 1, "저지": 2, "스웨이드": 3, "퍼": 4, "무스탕": 5
}
def encode_attributes(attributes):
    encoded_attributes = {
        "상위 카테고리": top_category_mapping.get(attributes.get("카테고리", ""), 0),
        "색상": color_mapping.get(attributes.get("색상", ""), 0),
        "소재": [material_mapping.get(m, 0) for m in attributes.get("소재", [])],
        # Add more attributes as needed
    }
    return encoded_attributes

# %%
# Change the output path of processed dataset
output_path = "/Users/dennycheong/YBIGTA/evenT/KFASHION_DATASET/processed"
if not os.path.exists(output_path):
    os.makedirs(output_path)

# Converts everything to COCO_Dataset format for individual image
def convert_to_coco_format(input_data):
    coco_format = {
        "info": {
            "description": "K-Fashion Dataset to COCO format",
            "version": "1.0",
            "year": 2024,
            "contributor": "evenT",
            "date_created": "2024-11-15"
        },
        "licenses": [],
        "images": [],
        "annotations": [],
        "categories": []
    }

    # Mapping of Categories
    categories = [
        {"id": 1, "name": "outer", "supercategory": "clothing"},
        {"id": 2, "name": "pants", "supercategory": "clothing"},
        {"id": 3, "name": "dress", "supercategory": "clothing"},
        {"id": 4, "name": "top", "supercategory": "clothing"}
    ]
    coco_format["categories"] = categories
    category_mapping = {
        "아우터": 1,  # outer
        "하의": 2,   # pants
        "원피스": 3, # dress
        "상의": 4    # top
    }

    annotation_id = 1  
    for item in input_data:
        if "이미지 정보" in item:
            image_info = {
                "id": item["이미지 정보"].get("이미지 식별자", -1),  # Default -1 if not found
                "file_name": item["이미지 정보"].get("이미지 파일명", ""),
                "width": item["이미지 정보"].get("이미지 너비", 0),
                "height": item["이미지 정보"].get("이미지 높이", 0),
            }
            coco_format["images"].append(image_info)

        if "데이터셋 정보" in item:
            rect_data = item["데이터셋 정보"]["데이터셋 상세설명"].get("렉트좌표", {})
            polygon_data = item["데이터셋 정보"]["데이터셋 상세설명"].get("폴리곤좌표", {})
            attributes_data = item["데이터셋 정보"]["데이터셋 상세설명"].get("라벨링", {}) 
            style_data = item["데이터셋 정보"]["데이터셋 상세설명"].get("스타일", [{}])[0]  

            style_category = style_data.get("스타일", "")
            substyle = style_data.get("서브스타일", "")
            style_encoded = encode_style(style_category, substyle)

            for category_name in category_mapping: 
                if category_name in rect_data and rect_data[category_name]:
                    for rect in rect_data[category_name]:
                        if rect:  
                            bbox = [
                                rect.get("X좌표", 0),
                                rect.get("Y좌표", 0),
                                rect.get("가로", 0),
                                rect.get("세로", 0)
                            ]
                            annotation = {
                                "id": annotation_id,
                                "image_id": item["이미지 정보"].get("이미지 식별자", -1),
                                "category_id": category_mapping[category_name],  
                                "bbox": bbox,
                                "area": rect.get("가로", 0) * rect.get("세로", 0),
                                "segmentation": [],  
                                "iscrowd": 0,
                                "style": style_encoded 
                            }

                            if category_name in polygon_data and polygon_data[category_name]:
                                for polygon in polygon_data[category_name]:
                                    if polygon:  
                                        segmentation = []
                                        for key in sorted(polygon.keys()):  
                                            if "X좌표" in key or "Y좌표" in key:
                                                segmentation.append(polygon[key])
                                        annotation["segmentation"].append(segmentation)

                            if category_name in attributes_data and attributes_data[category_name]:
                                encoded_attributes = encode_attributes(attributes_data[category_name][0])
                                annotation["attributes"] = encoded_attributes

                            coco_format["annotations"].append(annotation)
                            annotation_id += 1
    return coco_format

# %%
# Paths for input and output directories
test_path = "/root/evenT/Labels/Test"  
output_path = "/root/evenT/p_labels/test"  # Path of where I store the processed samples

if not os.path.exists(output_path):
    os.makedirs(output_path)

# %%
# Modifying each json file to each json file
for file_name in os.listdir(test_path):
    if file_name.endswith(".json"):  # Only process JSON files
        input_file = os.path.join(test_path, file_name)
        with open(input_file, 'r') as f:
            input_data = json.load(f)  # Load the data from the file

        # Convert data to COCO format
        converted_coco_data = convert_to_coco_format([input_data])  # Wrapping in list if function expects list

        # Extract file number or base name for naming the output
        file_number = os.path.splitext(file_name)[0]

        # Save to the specified output path with a modified filename
        output_file = os.path.join(output_path, f"modified_{file_number}.json")
        with open(output_file, 'w', encoding='utf-8') as f:
            json.dump(converted_coco_data, f, ensure_ascii=False, indent=4)

        print(f"Converted COCO format data saved at: {output_file}")
# Out:
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_1016530.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_1016553.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_1016618.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_1028690.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_1029079.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_1029101.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_1029473.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_1029756.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_1030283.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_1032387.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_1040980.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_1041004.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_1041320.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_1046476.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_1069768.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_1074395.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_1075782.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_1076482.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_1077491.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_1081420.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_1088635.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_1101.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_1116.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_1123695.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_1124275.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_1129780.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_1138936.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_1148.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_1152090.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_1153387.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_1155667.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_1159618.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_1160099.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_1162021.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_1162726.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_1162756.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_1162923.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_1162928.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_1162989.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_1163641.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_1163685.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_1163696.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_1163961.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_116572.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_1174459.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_11746.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_1175714.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_11994.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_132471.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_137932.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_15119.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_15593.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_15681.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_161385.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_162280.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_1710.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_174786.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_181251.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_181545.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_181594.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_198612.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_219658.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_223136.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_223974.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_224668.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_22928.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_240574.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_244007.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_268.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_278.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_278036.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_278107.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_282739.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_284.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_296.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_298.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_304.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_306098.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_306264.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_310836.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_312951.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_312965.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_314.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_316.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_323703.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_323817.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_326407.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_327507.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_330723.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_332.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_336.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_338.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_34058.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_341775.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_342.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_345111.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_356906.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_356978.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_360175.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_364777.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_367150.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_383903.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_384979.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_385049.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_38834.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_404081.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_404083.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_404114.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_406434.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_411365.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_411391.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_412009.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_412266.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_412370.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_412795.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_430602.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_448858.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_448915.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_449304.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_450828.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_451000.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_451543.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_454128.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_454173.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_456258.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_458884.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_459227.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_475157.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_475252.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_475773.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_476195.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_476312.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_477499.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_477507.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_477582.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_477949.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_478200.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_478404.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_478470.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_485984.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_486232.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_486302.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_486431.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_486902.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_487521.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_501339.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_505641.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_505652.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_506064.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_506128.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_506147.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_506200.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_507351.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_512369.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_521319.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_521648.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_526164.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_527651.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_527956.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_536008.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_536132.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_54400.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_607297.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_60869.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_609340.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_610778.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_611006.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_611077.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_615719.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_618143.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_618413.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_618719.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_619323.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_619459.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_620643.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_67243.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_679195.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_68476.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_694509.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_70375.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_715248.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_7566.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_76291.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_784852.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_784952.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_901239.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_9122.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_9130.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_918272.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_920572.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_933014.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_96540.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_971451.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_974418.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_976975.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_976976.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_976977.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_977116.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_982700.json
# Converted COCO format data saved at: /root/evenT/p_labels/test/modified_996201.json

# %%
put_path = "/root/evenT/p_labels/validation" 

i = 0 
for file_name in os.listdir(put_path):
    i += 1
print(i)
# Out:
# 1000

# %%
# This file is to modify json files and combine them into one
import re

# 
input_dir = '/root/evenT/Labels/Test'  # Directory containing individual JSON files
output_file = '/root/evenT/test_labels.json'  # Output combined annotation file

# Initialize COCO-style dictionary
combined_coco = {
    "info": {
        "description": "K-Fashion Dataset to COCO format",
        "version": "1.0",
        "year": 2024,
        "contributor": "evenT",
        "date_created": "2024-11-15"
    },
    "licenses": [],
    "images": [],
    "annotations": [],
    "categories": [
        {"id": 1, "name": "outer", "supercategory": "clothing"},
        {"id": 2, "name": "pants", "supercategory": "clothing"},
        {"id": 3, "name": "dress", "supercategory": "clothing"},
        {"id": 4, "name": "top", "supercategory": "clothing"}
    ]
}

annotation_id = 1  # Unique annotation ID counter

def extract_image_id(file_name):
    """Extracts the numeric image ID from a file name (e.g., {num}.jpg)."""
    match = re.search(r'(\d+)', file_name)
    return int(match.group(1)) if match else -1

for file_name in os.listdir(input_dir):
    if file_name.endswith('.json'):
        input_path = os.path.join(input_dir, file_name)
        with open(input_path, 'r') as f:
            input_data = json.load(f)  # Load the data from the file

        # Use your convert_to_coco_format function (assuming it works with a list input)
        converted_data = convert_to_coco_format([input_data])

        # Merge converted data into combined_coco
        for image in converted_data["images"]:
            image["id"] = extract_image_id(image["file_name"])  # Extract ID from file name
            combined_coco["images"].append(image)

        for annotation in converted_data["annotations"]:
            annotation["id"] = annotation_id
            combined_coco["annotations"].append(annotation)
            annotation_id += 1

# Save the combined COCO JSON file
with open(output_file, 'w', encoding='utf-8') as f:
    json.dump(combined_coco, f, ensure_ascii=False, indent=4)

print(f"Combined COCO-style annotation file created at: {output_file}")
# Out:
# Combined COCO-style annotation file created at: /root/evenT/test_labels.json
